# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Shift+enter")
# Out:
# Shift+enter

# %% [markdown]
# # python data types
# 1. int
# 2. float
# 3. boolean

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b=3.9
print(type(b))
print(b)
# Out:
# <class 'float'>
# 3.9

# %%
c=True
print(type(c))
print(c)
# Out:
# <class 'bool'>
# True
