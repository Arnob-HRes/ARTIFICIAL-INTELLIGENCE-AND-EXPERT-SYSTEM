# %% [markdown]
# # Python Data Types
# - List
# - Tuple
# - Set
# - Dictionary
# - Range

# %%
List=[1,2,3,"A",3.5]
print(type(List))
print(List)
# Out:
# <class 'list'>
# [1, 2, 3, 'A', 3.5]

# %%
#mutable
print(len(List))
# Out:
# 5

# %%
print(List[1])
# Out:
# 2

# %%
List[1]=100
print(List)
# Out:
# [1, 100, 3, 'A', 3.5]

# %%
List.append(200)
print(List)
# Out:
# [1, 100, 3, 'A', 3.5, 200]

# %%
List.insert(0,1000)
print(List)
# Out:
# [1000, 1, 100, 3, 'A', 3.5, 200]

# %%
List.pop()
print(List)
# Out:
# [1000, 1, 100, 3, 'A', 3.5]

# %%
list1=[10,20,30,40]
list1.append(50)
print(list1)
# Out:
# [10, 20, 30, 40, 50]

# %%
x=list1.pop()
print(x)
print(list1)
# Out:
# 50
# [10, 20, 30, 40]

# %%
name=[]
name.append("Richard")
name.append("Jonathon")
print(name)
print(len(name))
# Out:
# ['Richard', 'Jonathon']
# 2

# %%
List1=[10,20,30,40,50]
print(List1[2:4])
# Out:
# [30, 40]

# %% [markdown]
# # String

# %%
str="I love python"
print(type(str))
# Out:
# <class 'str'>

# %%
print(len(str))
# Out:
# 13

# %%
print(str[0])
# Out:
# I

# %%
print(str[2])
# Out:
# l

# %%
print(str[len(str)-1])
# Out:
# n

# %%
# slicing 
print(str[2:6])
# Out:
# love

# %%
print(str[:8])
# Out:
# I love p

# %%
print(str[3:])
# Out:
# ove python

# %%
print(str[-1])
# Out:
# n

# %%
print(str[-2])
# Out:
# o

# %%
str1="Richard Philip"
name=str1.upper()
print(name)
l_name=str1.lower()
print(l_name)
# Out:
# RICHARD PHILIP
# richard philip

# %%
str2="I love python\n I love Bangladesh"
x=str2.count("I")
print(x)
# Out:
# 2

# %%
str2="I love python\n I love Bangladesh"
l=str2.split(" ")
print(l)
# Out:
# ['I', 'love', 'python\n', 'I', 'love', 'Bangladesh']

# %%
str1="I love AI"
str2="I love Python"
str=str1+str2
print(str)
# Out:
# I love AII love Python

# %%
list=[10,20,30,40,50]
print(type(list))
# Out:
# <class 'list'>

# %%
print(len(list))
# Out:
# 5

# %%
print(list[0])
# Out:
# 10

# %%
list[0]=100
print(list)
# Out:
# [100, 20, 30, 40, 50]

# %%
list.append(1000)

# %%
print(list)
# Out:
# [100, 20, 30, 40, 50, 1000]

# %%
list.append(10)
print(list)
# Out:
# [100, 20, 30, 40, 50, 1000, 10]

# %%
x=list.pop()
print(x)
print(list)
# Out:
# 10
# [100, 20, 30, 40, 50, 1000]

# %%
print(list)
list.pop(0)
print(list)
# Out:
# [100, 20, 30, 40, 50, 1000]
# [20, 30, 40, 50, 1000]

# %%
print(list)
# Out:
# [20, 30, 40, 50, 1000]

# %%
print(len(list))
# Out:
# 5

# %%
list.clear()
print(list)
# Out:
# []

# %%
list.append(100)
print(list)
# Out:
# [100]

# %%
list=[]
list.append(20)
list.append(10)
print(list)
# Out:
# [20, 10]

# %%
list.sort()
print(list)
# Out:
# [10, 20]

# %%
list.reverse()
print(list)
# Out:
# [20, 10]

# %%
t=(10,20,30,10)
print(t.count(10))
print(type(t))
# Out:
# 2
# <class 'tuple'>

# %%
list=[10,20,30,40,20]
print(list.count(0))
# Out:
# 0

# %% [markdown]
# # Arithmetic Operator

# %%
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b) # floating division
print(a//b) # integer division
print(a**2) # exponent
print(a%b)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 100
# 10

# %% [markdown]
# # Realtional operator:
# - ==, !=, >=, >, <=,<
# # Logical Operator:
# - and, or, not

# %%
a=10
b=20
c=30
print(a>b)
# Out:
# False

# %%
print(a<=b)
# Out:
# True

# %%
print(a==b)
# Out:
# False

# %%
print(a !=b)
# Out:
# True

# %%
print((a>b) or (a<c))
# Out:
# True

# %%
x=(a>b) and (a<c)
print(x)
# Out:
# False

# %%
a=True
b=False
print(not a)
print(not (a and b))
# Out:
# False
# True

# %%
list=[10,20,30,40]
x= 10 in list
print(x)
# Out:
# True

# %%
x1=100 not in list
print(x1)
# Out:
# True

# %% [markdown]
# # conditional Statement

# %%
age=10
if age>=18:
    print("I am adult")  
else:
    print("I am not adult")
# Out:
# I am not adult

# %%
marks=90
if marks>=90:
    print("A+")
elif marks>=85 and marks<90:
    print("A")
else:
    print("I am not satisfied")
# Out:
# A+
